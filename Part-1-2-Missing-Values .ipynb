# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df0= pd.read_csv("autoscout_part1_clean.csv")
df = df0.copy()

# %%
df["last_service_date"] = df["last_service_date2"]
df.drop(["last_service_date2","description", "body_color_original", "body"], axis = 1, inplace = True)

# %%
df.head().T
# Out:
#                                                                          0  \
# make_model                                                         Audi A1
# body_type                                                           Sedans
# price                                                                15770
# vat                                                         VAT deductible
# km                                                                   56013
# registration                                                    2016-01-01
# hp                                                                    66.0
# type                                                                  Used
# previous_owners                                                        2.0
# warranty                                                               NaN
# first_registration                                              2016-01-01
# ...

# %%
reindex_df = df.reindex(columns=["make_model", "body_type", "price", "nr_of_doors", "nr_of_seats", "country_version", "type", "warranty",
    "availability", "available_from", "drive_chain", 
    "hp",  "gearing_type", "gears", "cylinders", "weight",
    "body_color", "paint_type", "upholstery_colors", "upholstery_type",
    "co2_emission", "emission_class", "emission_label", "comb_consumption",  "city_consumption", "country_consumption", "fuel",
    "comfort_convenience", "entertainment_media", "extras", "safety_security" ,
    "km",  "first_registration", "registration", "previous_owners", "inspection_new", "next_inspection",
    "vat", "displacement",
    "electricity_consumption", "last_service_date" ])
 #  electricity_consumption", "displacement", "last_service_date", "availability", "available_from", "drive_chain", "country_version" //drop later

# %%
difference = 0
for i in df.columns:
  if i not in reindex_df:
    difference += 1
print(difference)
# Out:
# 0

# %% [markdown]
# ## comfort_convenience

# %%
df["comfort_convenience"]
# Out:
# 0        ['Air conditioning', 'Armrest', 'Automatic cli...
# 1        ['Air conditioning', 'Automatic climate contro...
# 2        ['Air conditioning', 'Cruise control', 'Electr...
# 3        ['Air suspension', 'Armrest', 'Auxiliary heati...
# 4        ['Air conditioning', 'Armrest', 'Automatic cli...
#                                ...
# 15914    ['Air conditioning', 'Automatic climate contro...
# 15915    ['Air conditioning', 'Automatic climate contro...
# 15916    ['Air conditioning', 'Armrest', 'Automatic cli...
# 15917    ['Air conditioning', 'Automatic climate contro...
# 15918    ['Air conditioning', 'Automatic climate contro...
# Name: comfort_convenience, Length: 15919, dtype: object

# %%
df["comfort_convenience"] = [",".join(x) if type(x) == list else x for x in  df["comfort_convenience"]]

# %%
df["comfort_convenience"] = df["comfort_convenience"].astype(str)

# %%
df["comfort_convenience"] = df["comfort_convenience"].str.replace("[", "").str.replace("]", "")
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_11648\2076379015.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["comfort_convenience"] = df["comfort_convenience"].str.replace("[", "").str.replace("]", "")

# %%
df["comfort_convenience"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_11648\2259253801.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["comfort_convenience"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      920
# ...

# %%
df["comfort_convenience"][df["comfort_convenience"].str.count(".").argmax()]
# Out:
# "'Air conditioning', 'Armrest', 'Automatic climate control', 'Auxiliary heating', 'Cruise control', 'Electrically adjustable seats', 'Electrically heated windshield', 'Electrical side mirrors', 'Electric tailgate', 'Heads-up display', 'Heated steering wheel', 'Hill Holder', 'Keyless central door lock', 'Leather seats', 'Leather steering wheel', 'Light sensor', 'Lumbar support', 'Massage seats', 'Multi-function steering wheel', 'Navigation system', 'Panorama roof', 'Park Distance Control', 'Parking assist system camera', 'Parking assist system self-steering', 'Parking assist system sensors front', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Seat ventilation', 'Split rear seats', 'Start-stop system', 'Tinted windows'"

# %% [markdown]
# ## entertainment_media

# %%
df.comfort_convenience[0]
# Out:
# "'Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Hill Holder', 'Leather steering wheel', 'Light sensor', 'Multi-function steering wheel', 'Navigation system', 'Park Distance Control', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system'"

# %%
df["entertainment_media"] = df["entertainment_media"].astype(str)

# %%
df["entertainment_media"] = df["entertainment_media"].str.replace("[", "").str.replace("]", "")
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\854423604.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["entertainment_media"] = df["entertainment_media"].str.replace("[", "").str.replace("]", "")

# %%
df["entertainment_media"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\2148928937.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["entertainment_media"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# nan                                                                                                                           1374
# 'Bluetooth', 'Hands-free equipment', 'On-board computer', 'Radio', 'USB'                                                      1282
# 'Bluetooth', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'USB'                                                982
# 'Bluetooth', 'CD player', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'USB'                                   783
# ...

# %%
df["entertainment_media"][df["entertainment_media"].str.count(".").argmax()]
# Out:
# "'Bluetooth', 'CD player', 'Digital radio', 'Hands-free equipment', 'MP3', 'On-board computer', 'Radio', 'Sound system', 'Television', 'USB'"

# %% [markdown]
# ## extras

# %%
df.extras[0]
# Out:
# "['Alloy wheels', 'Catalytic Converter', 'Voice Control']"

# %%
df["extras"] = df["extras"].astype(str)

# %%
df["extras"] = df["extras"].str.replace("[", "").str.replace("]", "")
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\3695055401.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["extras"] = df["extras"].str.replace("[", "").str.replace("]", "")

# %%
df["extras"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\1161914729.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["extras"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# 'Alloy wheels'                                                                                                                 3245
# nan                                                                                                                            2962
# 'Alloy wheels', 'Touch screen'                                                                                                  697
# 'Alloy wheels', 'Voice Control'                                                                                                 577
# ...

# %%
df["extras"][df["extras"].str.count(".").argmax()]
# Out:
# "'Alloy wheels', 'Catalytic Converter', 'Shift paddles', 'Sport package', 'Sport seats', 'Sport suspension', 'Touch screen', 'Tuned car', 'Voice Control', 'Winter tyres'"

# %% [markdown]
# ## safety_security

# %%
df.comfort_convenience[0]
# Out:
# "'Air conditioning', 'Armrest', 'Automatic climate control', 'Cruise control', 'Electrical side mirrors', 'Hill Holder', 'Leather steering wheel', 'Light sensor', 'Multi-function steering wheel', 'Navigation system', 'Park Distance Control', 'Parking assist system sensors rear', 'Power windows', 'Rain sensor', 'Seat heating', 'Start-stop system'"

# %%
df["safety_security"] = df["safety_security"].astype(str)

# %%
df["safety_security"] = df["safety_security"].str.replace("[", "").str.replace("]", "")
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\214251705.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["safety_security"] = df["safety_security"].str.replace("[", "").str.replace("]", "")

# %%
df["safety_security"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_16088\3891366983.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["safety_security"].str.replace("[", "").str.replace("]", "").value_counts(dropna=False)
# nan                                                                                                                                                                                                                                                                                                                                                                                                                    982
# ...

# %%
df["safety_security"][df["safety_security"].str.count(".").argmax()]
# Out:
# "'ABS', 'Adaptive Cruise Control', 'Adaptive headlights', 'Alarm system', 'Blind spot monitor', 'Central door lock', 'Central door lock with remote control', 'Daytime running lights', 'Driver drowsiness detection', 'Driver-side airbag', 'Electronic stability control', 'Emergency brake assistant', 'Emergency system', 'Fog lights', 'Head airbag', 'Immobilizer', 'Isofix', 'Lane departure warning system', 'LED Daytime Running Lights', 'LED Headlights', 'Night view assist', 'Passenger-side airbag', 'Power steering', 'Rear airbag', 'Side airbag', 'Tire pressure monitoring system', 'Traction control', 'Traffic sign recognition', 'Xenon headlights'"

# %%
df.T
# Out:
#                                                                      0      \
# make_model                                                         Audi A1
# body_type                                                           Sedans
# price                                                                15770
# vat                                                         VAT deductible
# km                                                                   56013
# registration                                                    2016-01-01
# hp                                                                    66.0
# type                                                                  Used
# previous_owners                                                        2.0
# warranty                                                               NaN
# first_registration                                              2016-01-01
# ...

# %%
df.to_csv("autoscout_part1_2.csv", index=False)
